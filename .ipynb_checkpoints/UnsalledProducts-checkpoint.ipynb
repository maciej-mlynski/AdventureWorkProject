# %%
import pandas as pd
import numpy as np
import matplotlib as plt
# %matplotlib inline

# %%
df = pd.read_csv('UnsalledProducts.csv', sep=',', header=0)

# %%
df.drop('Unnamed: 0', axis=1,inplace=True)

# %%
# First I am going to delete products with no cat, and sub cat names, with no color, size, weight
df = df[9:]

# %%
df.groupby('CatName').count()['ProductID']
# Out:
# CatName
# Accessories     5
# Clothing        1
# Components     23
# Name: ProductID, dtype: int64

# %% [markdown]
# There is 23 components that did not sell at all. 5 Accessories and 1 clothing

# %%
df.groupby('SubCatName').count()['ProductID']
# Out:
# SubCatName
# Bottom Brackets     1
# Forks               1
# Handlebars          1
# Lights              3
# Mountain Frames     2
# Panniers            1
# Pumps               1
# Road Frames        13
# Saddles             1
# Shorts              1
# Touring Frames      1
# Wheels              3
# Name: ProductID, dtype: int64

# %%
df['CatName'].unique()
# Out:
# array(['Components', 'Clothing', 'Accessories'], dtype=object)

# %%
Components = df[df['CatName'] == 'Components']

# %%
Clothing = df[df['CatName'] == 'Clothing']

# %%
Accessories = df[df['CatName'] == 'Accessories']

# %%
Accessories
# Out:
#                             Name  ProductID ListPrice StandardCost Color Size  \
# 33     Headlights - Weatherproof        848     44,99      18,5584   NaN  NaN
# 34        Headlights - Dual-Beam        847     34,99      14,4334   NaN  NaN
# 35  Taillights - Battery-Powered        846     13,99       5,7709   NaN  NaN
# 36       Touring-Panniers, Large        842    125,00      51,5625  Grey  NaN
# 37                 Mountain Pump        845     24,99      10,3084   NaN  NaN
#
#    SizeUnitMeasureCode  Weight WeightUnitMeasureCode Style class SubCatName  \
# 33                 NaN     NaN                   NaN   NaN   NaN     Lights
# 34                 NaN     NaN                   NaN   NaN   NaN     Lights
# 35                 NaN     NaN                   NaN   NaN   NaN     Lights
# 36                 NaN     NaN                   NaN   NaN   NaN   Panniers
# 37                 NaN     NaN                   NaN   NaN   NaN      Pumps
#
# ...

# %%
Clothing
# Out:
#     ProductID ListPrice StandardCost  Color Size SizeUMC  Weight WeightUMC  \
# 32        851     59,99      24,7459  Black   XL     NaN     NaN       NaN
#
#    Style class SubCatName   CatName
# 32    M    NaN     Shorts  Clothing

# %%
Components
# Out:
#                               Name  ProductID ListPrice StandardCost   Color  \
# 9               ML Road Handlebars        812     61,92      27,4925     NaN
# 10               ML Bottom Bracket        995    101,24      44,9506     NaN
# 11                         ML Fork        803    175,49      77,9176     NaN
# 12   HL Mountain Frame - Black, 46        746   1349,60      739,041   Black
# 13  HL Mountain Frame - Silver, 44        740   1364,50      706,811  Silver
# 14       LL Road Frame - Black, 48        737    337,22     204,6251   Black
# 15         ML Road Frame - Red, 60        735    594,83     352,1394     Red
# 16         ML Road Frame - Red, 58        734    594,83     352,1394     Red
# 17         ML Road Frame - Red, 44        731    594,83     352,1394     Red
# 18         LL Road Frame - Red, 58        728    337,22     187,1571     Red
# 19       LL Road Frame - Black, 62        724    337,22     204,6251   Black
# ...
