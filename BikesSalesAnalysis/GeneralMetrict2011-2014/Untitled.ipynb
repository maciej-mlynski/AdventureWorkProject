# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
pd.set_option('display.max_columns', None)

sns.set(rc={'figure.figsize':(12,6)})

# %%
df1 = pd.read_csv('./../../PredictingYearlyOrderQuantity/Data/2011-2012OrdersQuantity.csv', sep=';')
df2 = pd.read_csv('./../../PredictingYearlyOrderQuantity/Data/2012-2013OrdersQuantity.csv', sep=';')
df3 = pd.read_csv('./../../PredictingYearlyOrderQuantity/Data/2013-2014OrdersQuantity.csv', sep=';')

# %%
df = pd.concat([df1,df2,df3])

# %%
df['UnitPriceDiscount'] = df[['UnitPriceDiscount']].applymap(lambda x: str(x.replace(',','.'))).astype('float64')
df['StanstadCost'] = df[['StanstadCost']].applymap(lambda x: str(x.replace(',','.'))).astype('float64')
df['ListPrice'] = df[['ListPrice']].applymap(lambda x: str(x.replace(',','.'))).astype('float64')
df['FinalSellPrice'] = df[['FinalSellPrice']].applymap(lambda x: str(x.replace(',','.'))).astype('float64')
df['PriceToCost'] = df[['PriceToCost']].applymap(lambda x: str(x.replace(',','.'))).astype('float64')

# %% [markdown]
# # Question 1
# #### What has incommone products sold under the standard costs?

# %%
np = df[df['PriceToCost'] < 1]

# %%
np
# Out:
#                 Name   Color  Size  UnitPriceDiscount  MonthsFromMay  \
# 0     Mountain Bikes   Black    38               0.35             11
# 24    Mountain Bikes   Black    42               0.35             11
# 46    Mountain Bikes   Black    44               0.35             11
# 69    Mountain Bikes   Black    48               0.35             11
# 89    Mountain Bikes  Silver    38               0.35             11
# ...              ...     ...   ...                ...            ...
# 1412   Touring Bikes  Yellow    62               0.00              3
# 1413   Touring Bikes  Yellow    62               0.00              4
# 1414   Touring Bikes  Yellow    62               0.00              5
# 1415   Touring Bikes  Yellow    62               0.00              6
# 1416   Touring Bikes  Yellow    62               0.00              7
#
#       MonthOfSale  YearsOfAveliability  Weight Class  StanstadCost  ListPrice  \
# 0               4                    0   20.35    H      1898.0944    3374.99
# 24              4                    0   20.77    H      1898.0944    3374.99
# 46              4                    0   21.13    H      1898.0944    3374.99
# 69              4                    0   21.42    H      1898.0944    3374.99
# 89              4                    0   20.35    H      1912.1544    3399.99
# ...           ...                  ...     ...   ...           ...        ...
# 1412            8                    0   30.00    L       461.4448     742.35
# 1413            9                    0   30.00    L       461.4448     742.35
# 1414           10                    0   30.00    L       461.4448     742.35
# 1415           11                    0   30.00    L       461.4448     742.35
# 1416           12                    0   30.00    L       461.4448     742.35
#
#       FinalSellPrice  PriceToCost  OrdersQuantity   YearsOfAnalyze
# 0           548.4359       0.2889              70  06.2011-06.2012
# 24          548.4359       0.2889              60  06.2011-06.2012
# 46          548.4359       0.2889              58  06.2011-06.2012
# 69          548.4359       0.2889              61  06.2011-06.2012
# 89          552.4984       0.2889              65  06.2011-06.2012
# ...              ...          ...             ...              ...
# 1412        445.4100       0.9652              29  06.2013-06.2014
# 1413        445.4100       0.9652              75  06.2013-06.2014
# 1414        445.4100       0.9652              85  06.2013-06.2014
# 1415        445.4100       0.9652              37  06.2013-06.2014
# 1416        445.4100       0.9652              38  06.2013-06.2014
#
# [1112 rows x 15 columns]
